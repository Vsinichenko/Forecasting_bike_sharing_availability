# %% [markdown]
# ### Imports

# %%
import pyreadr
import matplotlib.pyplot as plt
import pyinstrument
import pandas as pd
from tqdm.notebook import tqdm
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)
from datetime import datetime, timedelta

# %%
columns_to_keep = ["time_stamp", "bike_number", "bike", "uid", "lat", "lng", "name", "station_number"]

# %% [markdown]
# # Practice joins and filters

# %%
start_time = datetime(2024, 1, 31, 0, 3, 0)
#end_time = datetime(2024, 2, 1, 0, 00, 0)
current_time = start_time
current_filename = f'../data/Dresden_01-03.24/{current_time.strftime("%Y-%m-%d")}/{current_time.strftime("%Y-%m-%d-%H-%M-00")}.rds'
lag_time = current_time - timedelta(minutes=1)
lag_filename = f'../data/Dresden_01-03.24/{lag_time.strftime("%Y-%m-%d")}/{lag_time.strftime("%Y-%m-%d-%H-%M-00")}.rds'

# %%
result = pyreadr.read_r(current_filename)
df_current = result[None][columns_to_keep]

# %%
df_current
# Out:
#                time_stamp  bike_number   bike        uid        lat  \
# 0     2024-01-31 00:03:00       931104  False   32938439  51.056030
# 1     2024-01-31 00:03:00       930664  False   32938697  51.057930
# 2     2024-01-31 00:03:00       930803  False   32938910  51.077640
# 3     2024-01-31 00:03:00       931397  False   32938910  51.077640
# 4     2024-01-31 00:03:00       931637  False   32938910  51.077640
# ...                   ...          ...    ...        ...        ...
# 1163  2024-01-31 00:03:00       931202   True  353337278  51.078742
# 1164  2024-01-31 00:03:00       931640   True  353337283  51.042791
# 1165  2024-01-31 00:03:00       930086   True  353337316  51.047289
# 1166  2024-01-31 00:03:00       930489   True  353337320  51.084796
# 1167  2024-01-31 00:03:00       931058   True  353337326  51.043253
#
#             lng                     name station_number
# 0     13.722850  MOBIpunkt Bahnhof Mitte          43001
# 1     13.745820    MOBIpunkt Carolaplatz          43011
# 2     13.716860    MOBIpunkt Altpieschen          43015
# 3     13.716860    MOBIpunkt Altpieschen          43015
# 4     13.716860    MOBIpunkt Altpieschen          43015
# ...         ...                      ...            ...
# 1163  13.706899                      NaN            NaN
# 1164  13.736009                      NaN            NaN
# 1165  13.750616                      NaN            NaN
# 1166  13.727681                      NaN            NaN
# 1167  13.741752                      NaN            NaN
#
# [1168 rows x 8 columns]

# %%
result = pyreadr.read_r(lag_filename)
df_lag = result[None]

# %%
df_lag
# Out:
#          city           time_stamp        uid        lat        lng   bike  \
# 0     Dresden  2024-01-31 00:02:00   32938439  51.056030  13.722850  False
# 1     Dresden  2024-01-31 00:02:00   32938697  51.057930  13.745820  False
# 2     Dresden  2024-01-31 00:02:00   32938910  51.077640  13.716860  False
# 3     Dresden  2024-01-31 00:02:00   32938910  51.077640  13.716860  False
# 4     Dresden  2024-01-31 00:02:00   32938910  51.077640  13.716860  False
# ...       ...                  ...        ...        ...        ...    ...
# 1165  Dresden  2024-01-31 00:02:00  353337002  51.051480  13.741164   True
# 1166  Dresden  2024-01-31 00:02:00  353337012  51.076782  13.724803   True
# 1167  Dresden  2024-01-31 00:02:00  353337042  51.047329  13.750641   True
# 1168  Dresden  2024-01-31 00:02:00  353337062  51.084853  13.727458   True
# 1169  Dresden  2024-01-31 00:02:00  353337103  51.058204  13.724387   True
#
#                          name station_number  booked_bikes  bikes  \
# 0     MOBIpunkt Bahnhof Mitte          43001             0      1
# 1       MOBIpunkt Carolaplatz          43011             0      1
# 2       MOBIpunkt Altpieschen          43015             0      4
# 3       MOBIpunkt Altpieschen          43015             0      4
# 4       MOBIpunkt Altpieschen          43015             0      4
# ...                       ...            ...           ...    ...
# 1165                      NaN            NaN             0      1
# 1166                      NaN            NaN             0      1
# 1167                      NaN            NaN             0      1
# 1168                      NaN            NaN             0      1
# 1169                      NaN            NaN             0      1
#
#      bikes_available_to_rent bike_racks  free_racks  maintenance  \
# 0                          1          6           5        False
# 1                          1          5           4        False
# 2                          4          6           2        False
# 3                          4          6           2        False
# 4                          4          6           2        False
# ...                      ...        ...         ...          ...
# 1165                       1        NaN           0        False
# 1166                       1        NaN           0        False
# 1167                       1        NaN           0        False
# 1168                       1        NaN           0        False
# 1169                       1        NaN           0        False
#
#      terminal_type  place_type  rack_locks  no_registration  bike_number  \
# 0              NaN          18       False            False       931104
# 1              NaN          18       False            False       930664
# 2              NaN          18       False            False       930803
# 3              NaN          18       False            False       931432
# 4              NaN          18       False            False       931397
# ...            ...         ...         ...              ...          ...
# 1165           NaN          12       False            False       930530
# 1166           NaN          12       False            False       931357
# 1167           NaN          12       False            False       930086
# 1168           NaN          12       False            False       930489
# 1169           NaN          12       False            False       930417
#
#       bike_type      lock_types  active state  electric_lock  boardcomputer
# 0           150  frame_lock,dls    True    ok           True   7.551063e+09
# 1           150  frame_lock,dls    True    ok           True   7.551063e+09
# 2           196  frame_lock,dls    True    ok           True   7.551171e+09
# 3           196  frame_lock,dls    True    ok           True   7.551132e+09
# 4           196  frame_lock,dls    True    ok           True   7.551134e+09
# ...         ...             ...     ...   ...            ...            ...
# 1165        150  frame_lock,dls    True    ok           True   7.551063e+09
# 1166        196  frame_lock,dls    True    ok           True   7.551135e+09
# 1167        196  frame_lock,dls    True    ok           True   7.551160e+09
# 1168        150  frame_lock,dls    True    ok           True   7.551135e+09
# 1169        196  frame_lock,dls    True    ok           True   7.551171e+09
#
# [1170 rows x 25 columns]

# %% [markdown]
# df_merge = df_current[columns_to_keep].merge(df_lag[columns_to_keep],
#                                              on="bike_number", how="outer",
#                                              suffixes=("_current", "_lag"), validate="one_to_one", indicator=True)

# %% [markdown]
# df_merge.columns

# %% [markdown]
# df_merge[df_merge._merge!="both"]

# %%
df_lag[~df_lag.bike_number.isin(df_current.bike_number)][columns_to_keep]
# Out:
#                time_stamp  bike_number   bike        uid        lat  \
# 3     2024-01-31 00:02:00       931432  False   32938910  51.077640
# 161   2024-01-31 00:02:00       931334  False   45741034  51.072482
# 1144  2024-01-31 00:02:00       930470   True  353336303  51.037369
#
#             lng                         name station_number
# 3     13.716860        MOBIpunkt Altpieschen          43015
# 161   13.746493  S-Bf. Bischofsplatz (Hecht)          43072
# 1144  13.749184                          NaN            NaN

# %%
to_add_rent = df_lag[~df_lag.bike_number.isin(df_current.bike_number)][columns_to_keep]
to_add_rent
# Out:
#                time_stamp  bike_number   bike        uid        lat  \
# 3     2024-01-31 00:02:00       931432  False   32938910  51.077640
# 161   2024-01-31 00:02:00       931334  False   45741034  51.072482
# 1144  2024-01-31 00:02:00       930470   True  353336303  51.037369
#
#             lng                         name station_number
# 3     13.716860        MOBIpunkt Altpieschen          43015
# 161   13.746493  S-Bf. Bischofsplatz (Hecht)          43072
# 1144  13.749184                          NaN            NaN

# %%
to_add_rent = df_lag[~df_lag.bike_number.isin(df_current.bike_number.tolist())][columns_to_keep]
to_add_rent["rent_or_return"] = "rent"

# %%
df = pd.DataFrame()

# %%
df = pd.concat([df, to_add_rent], ignore_index=True)

# %%
df
# Out:
#             time_stamp  bike_number   bike        uid        lat        lng  \
# 0  2024-01-31 00:02:00       931432  False   32938910  51.077640  13.716860
# 1  2024-01-31 00:02:00       931334  False   45741034  51.072482  13.746493
# 2  2024-01-31 00:02:00       930470   True  353336303  51.037369  13.749184
#
#                           name station_number rent_or_return
# 0        MOBIpunkt Altpieschen          43015           rent
# 1  S-Bf. Bischofsplatz (Hecht)          43072           rent
# 2                          NaN            NaN           rent

# %%
to_add_rent
# Out:
#                time_stamp  bike_number   bike        uid        lat  \
# 3     2024-01-31 00:02:00       931432  False   32938910  51.077640
# 161   2024-01-31 00:02:00       931334  False   45741034  51.072482
# 1144  2024-01-31 00:02:00       930470   True  353336303  51.037369
#
#             lng                         name station_number rent_or_return
# 3     13.716860        MOBIpunkt Altpieschen          43015           rent
# 161   13.746493  S-Bf. Bischofsplatz (Hecht)          43072           rent
# 1144  13.749184                          NaN            NaN           rent

# %%
df_current[~df_current.bike_number.isin(df_lag.bike_number)][columns_to_keep]
# Out:
#              time_stamp  bike_number   bike       uid       lat       lng  \
# 68  2024-01-31 00:03:00       931033  False  32940489  51.05986  13.71834
#
#                         name station_number
# 68  MOBIpunkt Friedrichstadt          43024

# %% [markdown]
# # Iterate over datasets to create df of rents and returns

# %%
def get_filename(time):
    return f'../data/Dresden_01-03.24/{time.strftime("%Y-%m-%d")}/{time.strftime("%Y-%m-%d-%H-%M-00")}.rds'

# %%
rent_list = []
return_list = []

# %%
start_time = datetime(2024, 3, 27, 14, 52, 0) # the second filename
end_time = datetime(2024, 3, 31, 23, 59, 0) # the very last filename


lag_time = start_time - timedelta(minutes=1)
lag_filename = get_filename(lag_time)
df_lag = pyreadr.read_r(lag_filename)[None][columns_to_keep]
lag_bike_numbers = set(df_lag.bike_number)

for current_time in tqdm(pd.date_range(start=start_time, end=end_time, freq="min")):
        current_filename = get_filename(current_time)
        try:
                df_current = pyreadr.read_r(current_filename)[None][columns_to_keep]
                current_bike_numbers = set(df_current.bike_number)

                rented_bikes = df_lag[df_lag.bike_number.isin(lag_bike_numbers-current_bike_numbers)]
                if not rented_bikes.empty:
                        rent_list.extend(rented_bikes.to_dict(orient="records"))

                returned_bikes = df_current[df_current.bike_number.isin(current_bike_numbers-lag_bike_numbers)]
                if not returned_bikes.empty:
                        return_list.extend(returned_bikes.to_dict(orient="records"))
                
                df_lag = df_current
                lag_bike_numbers = current_bike_numbers
        except Exception as e:
                pass
# Out:
#   0%|          | 0/6308 [00:00<?, ?it/s]

# %%
current_time # Timestamp('2024-03-15 06:17:00')
# Out:
# Timestamp('2024-03-27 14:52:00')

# %%
df = pd.DataFrame(rent_list)
df['rent_or_return']="rent"
df_return = pd.DataFrame(return_list)
df_return['rent_or_return']="returns" # return is a reserved word
df = pd.concat([df,df_return], ignore_index=True)
df = df.sort_values(["bike_number", "time_stamp"])

# %%
df.time_stamp.max()
# Out:
# '2024-03-31 23:59:00'

# %%
df.dtypes
# Out:
# time_stamp         object
# bike_number         int64
# bike                 bool
# uid                 int64
# lat               float64
# lng               float64
# name               object
# station_number    float64
# rent_or_return     object
# dtype: object

# %%
df.time_stamp.min()
# Out:
# '2024-01-01 00:02:00'

# %%
df.time_stamp.apply(len).unique()
# Out:
# array([19, 10])

# %%
df.time_stamp = df.time_stamp.apply(lambda x: x + " 00:00:00" if len(x) == 10 else x)

# %%
df["date"]=pd.to_datetime(df.time_stamp).dt.date

# %%
file_path = "../data/rents_returns_by_bike_Dresden_01-03.24.pkl"

# %%
df.to_pickle(file_path)

# %% [markdown]
# # corrections

# %%
df = pd.read_pickle(file_path)

# %%
df.bike_number = df.bike_number.astype(int)

# %%
df
# Out:
#                  time_stamp  bike_number   bike        uid        lat  \
# 481181  2024-01-19 08:43:00       930000  False   32939517  51.048930
# 64361   2024-01-21 15:39:00       930000  False   32939517  51.048930
# 486104  2024-01-21 15:46:00       930000  False   32939517  51.048930
# 64421   2024-01-21 15:50:00       930000  False   32939517  51.048930
# 486217  2024-01-21 16:09:00       930000   True  348898836  51.033422
# ...                     ...          ...    ...        ...        ...
# 830000  2024-03-28 17:02:00       932013  False  382962921  48.134627
# 407930  2024-03-28 17:34:00       932013  False  382962921  48.134627
# 830216  2024-03-28 17:39:00       932013  False  382962921  48.134627
# 408412  2024-03-28 18:42:00       932013  False  382962921  48.134627
# 830713  2024-03-28 18:50:00       932013   True  383040862  48.133618
#
#               lng                         name  station_number rent_or_return  \
# 481181  13.744200  MOBIpunkt Pirnaischer Platz           43003        returns
# 64361   13.744200  MOBIpunkt Pirnaischer Platz           43003           rent
# 486104  13.744200  MOBIpunkt Pirnaischer Platz           43003        returns
# 64421   13.744200  MOBIpunkt Pirnaischer Platz           43003           rent
# 486217  13.707902                          NaN            <NA>        returns
# ...           ...                          ...             ...            ...
# 830000  11.610754                   Mentz Büro           32432        returns
# 407930  11.610754                   Mentz Büro           32432           rent
# 830216  11.610754                   Mentz Büro           32432        returns
# 408412  11.610754                   Mentz Büro           32432           rent
# 830713  11.608149                          NaN            <NA>        returns
#
#               date            datetime       datetime_hour
# 481181  2024-01-19 2024-01-19 08:43:00 2024-01-19 08:00:00
# 64361   2024-01-21 2024-01-21 15:39:00 2024-01-21 15:00:00
# 486104  2024-01-21 2024-01-21 15:46:00 2024-01-21 15:00:00
# 64421   2024-01-21 2024-01-21 15:50:00 2024-01-21 15:00:00
# 486217  2024-01-21 2024-01-21 16:09:00 2024-01-21 16:00:00
# ...            ...                 ...                 ...
# 830000  2024-03-28 2024-03-28 17:02:00 2024-03-28 17:00:00
# 407930  2024-03-28 2024-03-28 17:34:00 2024-03-28 17:00:00
# 830216  2024-03-28 2024-03-28 17:39:00 2024-03-28 17:00:00
# 408412  2024-03-28 2024-03-28 18:42:00 2024-03-28 18:00:00
# 830713  2024-03-28 2024-03-28 18:50:00 2024-03-28 18:00:00
#
# [843909 rows x 12 columns]

# %%
df["datetime"]= pd.to_datetime(df.time_stamp)

# %%
df["datetime_hour"]= df.datetime.dt.floor(freq="h")

# %%
df.station_number = df.station_number.astype(pd.Int64Dtype())

# %%
df
# Out:
#                  time_stamp  bike_number   bike        uid        lat  \
# 481181  2024-01-19 08:43:00       930000  False   32939517  51.048930
# 64361   2024-01-21 15:39:00       930000  False   32939517  51.048930
# 486104  2024-01-21 15:46:00       930000  False   32939517  51.048930
# 64421   2024-01-21 15:50:00       930000  False   32939517  51.048930
# 486217  2024-01-21 16:09:00       930000   True  348898836  51.033422
# ...                     ...          ...    ...        ...        ...
# 830000  2024-03-28 17:02:00       932013  False  382962921  48.134627
# 407930  2024-03-28 17:34:00       932013  False  382962921  48.134627
# 830216  2024-03-28 17:39:00       932013  False  382962921  48.134627
# 408412  2024-03-28 18:42:00       932013  False  382962921  48.134627
# 830713  2024-03-28 18:50:00       932013   True  383040862  48.133618
#
#               lng                         name  station_number rent_or_return  \
# 481181  13.744200  MOBIpunkt Pirnaischer Platz           43003        returns
# 64361   13.744200  MOBIpunkt Pirnaischer Platz           43003           rent
# 486104  13.744200  MOBIpunkt Pirnaischer Platz           43003        returns
# 64421   13.744200  MOBIpunkt Pirnaischer Platz           43003           rent
# 486217  13.707902                          NaN            <NA>        returns
# ...           ...                          ...             ...            ...
# 830000  11.610754                   Mentz Büro           32432        returns
# 407930  11.610754                   Mentz Büro           32432           rent
# 830216  11.610754                   Mentz Büro           32432        returns
# 408412  11.610754                   Mentz Büro           32432           rent
# 830713  11.608149                          NaN            <NA>        returns
#
#               date            datetime       datetime_hour
# 481181  2024-01-19 2024-01-19 08:43:00 2024-01-19 08:00:00
# 64361   2024-01-21 2024-01-21 15:39:00 2024-01-21 15:00:00
# 486104  2024-01-21 2024-01-21 15:46:00 2024-01-21 15:00:00
# 64421   2024-01-21 2024-01-21 15:50:00 2024-01-21 15:00:00
# 486217  2024-01-21 2024-01-21 16:09:00 2024-01-21 16:00:00
# ...            ...                 ...                 ...
# 830000  2024-03-28 2024-03-28 17:02:00 2024-03-28 17:00:00
# 407930  2024-03-28 2024-03-28 17:34:00 2024-03-28 17:00:00
# 830216  2024-03-28 2024-03-28 17:39:00 2024-03-28 17:00:00
# 408412  2024-03-28 2024-03-28 18:42:00 2024-03-28 18:00:00
# 830713  2024-03-28 2024-03-28 18:50:00 2024-03-28 18:00:00
#
# [843909 rows x 12 columns]

# %%
len(df)
# Out:
# 843909

# %%
def filter_group(group):
    if group.iloc[0]['rent_or_return'] == "returns":
        group = group.iloc[1:]
    return group

# %%
df = df.groupby('bike_number', group_keys=False).apply(filter_group)
# Out:
# /var/folders/zz/b00th7c11zqbbg9m2fhn24d40000gp/T/ipykernel_2860/3302797301.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('bike_number', group_keys=False).apply(filter_group)

# %%
df.to_pickle(file_path)
