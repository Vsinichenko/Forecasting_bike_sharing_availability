# %% [markdown]
# ### About the df
# Each row is a bike. Only currently parked bikes are shown in each datta table.

# %% [markdown]
# ### **Column meanings:**
#
# * city
# * time_stamp
# * uid - another station ID, identifies station; but, if bike is free floating, the uique uid will be assigned
# * lat
# * lng
# * bike - True means bike is free-floating; False meand bike is parked at a station
# * name - station name, identifies station
# * station_number - sation ID, identifies station
# * booked_bikes - I guess, iif a bike is currently booked, the field equals 1, otherwise 0
# * bikes
# * bikes_available_to_rent
# * bike_racks
# * free_racks
# * maintenance - boolean, probably means that a station needs maintenance
# * terminal_type - missing for free floating bikes, missing for stations where bikes are blocked, "free" for actual stations where bikes are not blocked by racks, like in Dresden "Hauptbahnhof Nord" station
# * place_type - 12 for free floating bikes, the rest are unique characteristic of a station
# * rack_locks
# * no_registration
# * bike_number - unique ID of a bike, identifies a bike
# * bike_type
# * lock_types
# * active
# * state
# * electric_lock
# * boardcomputer - unique ID of bike's boardcomputer

# %%
import pyreadr
import seaborn as sns
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %% [markdown]
# # nighttime df

# %%
result = pyreadr.read_r('../data/Dresden_01-03.24/2024-01-01/2024-01-01-23-59-00.rds')
df = result[None]

# %%
df.columns
# Out:
# Index(['city', 'time_stamp', 'uid', 'lat', 'lng', 'bike', 'name',
#        'station_number', 'booked_bikes', 'bikes', 'bikes_available_to_rent',
#        'bike_racks', 'free_racks', 'maintenance', 'terminal_type',
#        'place_type', 'rack_locks', 'no_registration', 'bike_number',
#        'bike_type', 'lock_types', 'active', 'state', 'electric_lock',
#        'boardcomputer'],
#       dtype='object')

# %%
len(df)
# Out:
# 971

# %%
df[df.booked_bikes==1]
# Out:
#         city           time_stamp        uid        lat        lng   bike  \
# 16   Dresden  2024-01-01 23:59:00   32939177  51.051397  13.804321  False
# 686  Dresden  2024-01-01 23:59:00  339542264  51.036684  13.761790   True
# 872  Dresden  2024-01-01 23:59:00  339561638  51.070622  13.764087   True
#
#                         name station_number  booked_bikes  bikes  \
# 16   MOBIpunkt Schillerplatz          43008             1      1
# 686                      NaN            NaN             1      1
# 872                      NaN            NaN             1      1
#
#     bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 16                      NaN          6           5        False           NaN
# 686                     NaN        NaN           0        False           NaN
# 872                     NaN        NaN           0        False           NaN
#
#      place_type  rack_locks  no_registration  bike_number  bike_type  \
# 16           21       False            False       931506        196
# 686          12       False            False       930113        196
# 872          12       False            False       930752        196
#
#          lock_types  active state  electric_lock  boardcomputer
# 16   frame_lock,dls    True    ok           True   7.551153e+09
# 686  frame_lock,dls    True    ok           True   7.551155e+09
# 872  frame_lock,dls    True    ok           True   7.551155e+09

# %%
df.sort_values("uid").head(10)
# Out:
#        city           time_stamp       uid       lat       lng   bike  \
# 0   Dresden  2024-01-01 23:59:00  32938439  51.05603  13.72285  False
# 1   Dresden  2024-01-01 23:59:00  32938439  51.05603  13.72285  False
# 2   Dresden  2024-01-01 23:59:00  32938439  51.05603  13.72285  False
# 3   Dresden  2024-01-01 23:59:00  32938697  51.05793  13.74582  False
# 4   Dresden  2024-01-01 23:59:00  32938697  51.05793  13.74582  False
# 5   Dresden  2024-01-01 23:59:00  32938697  51.05793  13.74582  False
# 7   Dresden  2024-01-01 23:59:00  32938697  51.05793  13.74582  False
# 6   Dresden  2024-01-01 23:59:00  32938697  51.05793  13.74582  False
# 8   Dresden  2024-01-01 23:59:00  32938697  51.05793  13.74582  False
# 11  Dresden  2024-01-01 23:59:00  32938910  51.07764  13.71686  False
#
#                        name station_number  booked_bikes  bikes  \
# 0   MOBIpunkt Bahnhof Mitte          43001             0      3
# 1   MOBIpunkt Bahnhof Mitte          43001             0      3
# 2   MOBIpunkt Bahnhof Mitte          43001             0      3
# 3     MOBIpunkt Carolaplatz          43011             0      6
# 4     MOBIpunkt Carolaplatz          43011             0      6
# 5     MOBIpunkt Carolaplatz          43011             0      6
# 7     MOBIpunkt Carolaplatz          43011             0      6
# 6     MOBIpunkt Carolaplatz          43011             0      6
# 8     MOBIpunkt Carolaplatz          43011             0      6
# 11    MOBIpunkt Altpieschen          43015             0      6
#
#    bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 0                        3          6           3        False           NaN
# 1                        3          6           3        False           NaN
# 2                        3          6           3        False           NaN
# 3                        6          5           0        False           NaN
# 4                        6          5           0        False           NaN
# 5                        6          5           0        False           NaN
# 7                        6          5           0        False           NaN
# 6                        6          5           0        False           NaN
# 8                        6          5           0        False           NaN
# 11                       6          6           0        False           NaN
#
#     place_type  rack_locks  no_registration  bike_number  bike_type  \
# 0           18       False            False       931025        150
# 1           18       False            False       930497        196
# 2           18       False            False       931639        196
# 3           18       False            False       930843        150
# 4           18       False            False       930467        196
# 5           18       False            False       930347        196
# 7           18       False            False       931771        196
# 6           18       False            False       931384        196
# 8           18       False            False       931507        196
# 11          18       False            False       931336        196
#
#         lock_types  active state  electric_lock  boardcomputer
# 0   frame_lock,dls    True    ok           True   7.551015e+09
# 1   frame_lock,dls    True    ok           True   7.551154e+09
# 2   frame_lock,dls    True    ok           True   7.551153e+09
# 3   frame_lock,dls    True    ok           True   7.551060e+09
# 4   frame_lock,dls    True    ok           True   7.551168e+09
# 5   frame_lock,dls    True    ok           True   7.551169e+09
# 7   frame_lock,dls    True    ok           True   7.551153e+09
# 6   frame_lock,dls    True    ok           True   7.551132e+09
# 8   frame_lock,dls    True    ok           True   7.551153e+09
# 11  frame_lock,dls    True    ok           True   7.551164e+09

# %%
df[df.booked_bikes!=0]
# Out:
#         city           time_stamp        uid        lat        lng   bike  \
# 16   Dresden  2024-01-01 23:59:00   32939177  51.051397  13.804321  False
# 686  Dresden  2024-01-01 23:59:00  339542264  51.036684  13.761790   True
# 872  Dresden  2024-01-01 23:59:00  339561638  51.070622  13.764087   True
#
#                         name station_number  booked_bikes  bikes  \
# 16   MOBIpunkt Schillerplatz          43008             1      1
# 686                      NaN            NaN             1      1
# 872                      NaN            NaN             1      1
#
#     bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 16                      NaN          6           5        False           NaN
# 686                     NaN        NaN           0        False           NaN
# 872                     NaN        NaN           0        False           NaN
#
#      place_type  rack_locks  no_registration  bike_number  bike_type  \
# 16           21       False            False       931506        196
# 686          12       False            False       930113        196
# 872          12       False            False       930752        196
#
#          lock_types  active state  electric_lock  boardcomputer
# 16   frame_lock,dls    True    ok           True   7.551153e+09
# 686  frame_lock,dls    True    ok           True   7.551155e+09
# 872  frame_lock,dls    True    ok           True   7.551155e+09

# %%
len(df.name.unique())
# Out:
# 120

# %%
df.terminal_type.unique()
# Out:
# [NaN, 'free']
# Categories (1, object): ['free']

# %%
len(df.uid.unique())
# Out:
# 811

# %%
df[df.station_number==43001]
# Out:
#       city           time_stamp       uid       lat       lng   bike  \
# 0  Dresden  2024-01-01 23:59:00  32938439  51.05603  13.72285  False
# 1  Dresden  2024-01-01 23:59:00  32938439  51.05603  13.72285  False
# 2  Dresden  2024-01-01 23:59:00  32938439  51.05603  13.72285  False
#
#                       name station_number  booked_bikes  bikes  \
# 0  MOBIpunkt Bahnhof Mitte          43001             0      3
# 1  MOBIpunkt Bahnhof Mitte          43001             0      3
# 2  MOBIpunkt Bahnhof Mitte          43001             0      3
#
#   bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 0                       3          6           3        False           NaN
# 1                       3          6           3        False           NaN
# 2                       3          6           3        False           NaN
#
#    place_type  rack_locks  no_registration  bike_number  bike_type  \
# 0          18       False            False       931025        150
# 1          18       False            False       930497        196
# 2          18       False            False       931639        196
#
#        lock_types  active state  electric_lock  boardcomputer
# 0  frame_lock,dls    True    ok           True   7.551015e+09
# 1  frame_lock,dls    True    ok           True   7.551154e+09
# 2  frame_lock,dls    True    ok           True   7.551153e+09

# %%
df[df.uid==32938439]
# Out:
#       city           time_stamp       uid       lat       lng   bike  \
# 0  Dresden  2024-01-01 23:59:00  32938439  51.05603  13.72285  False
# 1  Dresden  2024-01-01 23:59:00  32938439  51.05603  13.72285  False
# 2  Dresden  2024-01-01 23:59:00  32938439  51.05603  13.72285  False
#
#                       name station_number  booked_bikes  bikes  \
# 0  MOBIpunkt Bahnhof Mitte          43001             0      3
# 1  MOBIpunkt Bahnhof Mitte          43001             0      3
# 2  MOBIpunkt Bahnhof Mitte          43001             0      3
#
#   bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 0                       3          6           3        False           NaN
# 1                       3          6           3        False           NaN
# 2                       3          6           3        False           NaN
#
#    place_type  rack_locks  no_registration  bike_number  bike_type  \
# 0          18       False            False       931025        150
# 1          18       False            False       930497        196
# 2          18       False            False       931639        196
#
#        lock_types  active state  electric_lock  boardcomputer
# 0  frame_lock,dls    True    ok           True   7.551015e+09
# 1  frame_lock,dls    True    ok           True   7.551154e+09
# 2  frame_lock,dls    True    ok           True   7.551153e+09

# %%
df[df.terminal_type.isna()]
# Out:
#         city           time_stamp        uid        lat        lng   bike  \
# 0    Dresden  2024-01-01 23:59:00   32938439  51.056030  13.722850  False
# 1    Dresden  2024-01-01 23:59:00   32938439  51.056030  13.722850  False
# 2    Dresden  2024-01-01 23:59:00   32938439  51.056030  13.722850  False
# 3    Dresden  2024-01-01 23:59:00   32938697  51.057930  13.745820  False
# 4    Dresden  2024-01-01 23:59:00   32938697  51.057930  13.745820  False
# ..       ...                  ...        ...        ...        ...    ...
# 966  Dresden  2024-01-01 23:59:00  339574996  51.094324  13.726396   True
# 967  Dresden  2024-01-01 23:59:00  339575015  51.052240  13.757703   True
# 968  Dresden  2024-01-01 23:59:00  339575073  51.041489  13.730721   True
# 969  Dresden  2024-01-01 23:59:00  339575105  51.090684  13.711403   True
# 970  Dresden  2024-01-01 23:59:00  339575114  51.046831  13.795672   True
#
#                         name station_number  booked_bikes  bikes  \
# 0    MOBIpunkt Bahnhof Mitte          43001             0      3
# 1    MOBIpunkt Bahnhof Mitte          43001             0      3
# 2    MOBIpunkt Bahnhof Mitte          43001             0      3
# 3      MOBIpunkt Carolaplatz          43011             0      6
# 4      MOBIpunkt Carolaplatz          43011             0      6
# ..                       ...            ...           ...    ...
# 966                      NaN            NaN             0      1
# 967                      NaN            NaN             0      1
# 968                      NaN            NaN             0      1
# 969                      NaN            NaN             0      1
# 970                      NaN            NaN             0      1
#
#     bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 0                         3          6           3        False           NaN
# 1                         3          6           3        False           NaN
# 2                         3          6           3        False           NaN
# 3                         6          5           0        False           NaN
# 4                         6          5           0        False           NaN
# ..                      ...        ...         ...          ...           ...
# 966                       1        NaN           0        False           NaN
# 967                       1        NaN           0        False           NaN
# 968                       1        NaN           0        False           NaN
# 969                       1        NaN           0        False           NaN
# 970                       1        NaN           0        False           NaN
#
#      place_type  rack_locks  no_registration  bike_number  bike_type  \
# 0            18       False            False       931025        150
# 1            18       False            False       930497        196
# 2            18       False            False       931639        196
# 3            18       False            False       930843        150
# 4            18       False            False       930467        196
# ..          ...         ...              ...          ...        ...
# 966          12       False            False       930756        150
# 967          12       False            False       931658        196
# 968          12       False            False       930069        196
# 969          12       False            False       930375        196
# 970          12       False            False       930245        196
#
#          lock_types  active state  electric_lock  boardcomputer
# 0    frame_lock,dls    True    ok           True   7.551015e+09
# 1    frame_lock,dls    True    ok           True   7.551154e+09
# 2    frame_lock,dls    True    ok           True   7.551153e+09
# 3    frame_lock,dls    True    ok           True   7.551060e+09
# 4    frame_lock,dls    True    ok           True   7.551168e+09
# ..              ...     ...   ...            ...            ...
# 966  frame_lock,dls    True    ok           True   7.551048e+09
# 967  frame_lock,dls    True    ok           True   7.551154e+09
# 968  frame_lock,dls    True    ok           True   7.551163e+09
# 969  frame_lock,dls    True    ok           True   7.551170e+09
# 970  frame_lock,dls    True    ok           True   7.551141e+09
#
# [816 rows x 25 columns]

# %%
df.groupby(["bike", "terminal_type"]).size()
# Out:
# /var/folders/zz/b00th7c11zqbbg9m2fhn24d40000gp/T/ipykernel_2586/354040936.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["bike", "terminal_type"]).size()
# bike   terminal_type
# False  free             155
# True   free               0
# dtype: int64

# %%
len(df.station_number.unique())
# Out:
# 120

# %%
df.tail()
# Out:
#         city           time_stamp        uid        lat        lng  bike name  \
# 966  Dresden  2024-01-01 23:59:00  339574996  51.094324  13.726396  True  NaN
# 967  Dresden  2024-01-01 23:59:00  339575015  51.052240  13.757703  True  NaN
# 968  Dresden  2024-01-01 23:59:00  339575073  51.041489  13.730721  True  NaN
# 969  Dresden  2024-01-01 23:59:00  339575105  51.090684  13.711403  True  NaN
# 970  Dresden  2024-01-01 23:59:00  339575114  51.046831  13.795672  True  NaN
#
#     station_number  booked_bikes  bikes bikes_available_to_rent bike_racks  \
# 966            NaN             0      1                       1        NaN
# 967            NaN             0      1                       1        NaN
# 968            NaN             0      1                       1        NaN
# 969            NaN             0      1                       1        NaN
# 970            NaN             0      1                       1        NaN
#
#      free_racks  maintenance terminal_type  place_type  rack_locks  \
# 966           0        False           NaN          12       False
# 967           0        False           NaN          12       False
# 968           0        False           NaN          12       False
# 969           0        False           NaN          12       False
# 970           0        False           NaN          12       False
#
#      no_registration  bike_number  bike_type      lock_types  active state  \
# 966            False       930756        150  frame_lock,dls    True    ok
# 967            False       931658        196  frame_lock,dls    True    ok
# 968            False       930069        196  frame_lock,dls    True    ok
# 969            False       930375        196  frame_lock,dls    True    ok
# 970            False       930245        196  frame_lock,dls    True    ok
#
#      electric_lock  boardcomputer
# 966           True   7.551048e+09
# 967           True   7.551154e+09
# 968           True   7.551163e+09
# 969           True   7.551170e+09
# 970           True   7.551141e+09

# %%
df.describe()
# Out:
#                 uid         lat         lng  booked_bikes       bikes  \
# count  9.710000e+02  971.000000  971.000000    971.000000  971.000000
# mean   2.738726e+08   51.048788   13.756116      0.003090    2.077240
# std    1.126244e+08    0.023837    0.042453      0.055527    2.673506
# min    3.293844e+07   50.985100   13.662797      0.000000    1.000000
# 25%    2.186095e+08   51.034208   13.725034      0.000000    1.000000
# 50%    3.395076e+08   51.048009   13.748583      0.000000    1.000000
# 75%    3.395466e+08   51.060925   13.784128      0.000000    1.000000
# max    3.395751e+08   51.128603   13.893708      1.000000   13.000000
#
#        free_racks  place_type    bike_number   bike_type  boardcomputer
# count  971.000000  971.000000     971.000000  971.000000   9.710000e+02
# mean     0.165808   13.630278  930973.774459  186.024717   8.019201e+09
# std      0.777456    2.617205     541.227754   19.826396   5.939090e+09
# min      0.000000   12.000000  930001.000000  150.000000   7.551004e+09
# 25%      0.000000   12.000000  930484.000000  196.000000   7.551134e+09
# 50%      0.000000   12.000000  931031.000000  196.000000   7.551153e+09
# 75%      0.000000   17.000000  931454.500000  196.000000   7.551163e+09
# max      9.000000   22.000000  931806.000000  283.000000   8.330000e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   city                     971 non-null    category
#  1   time_stamp               971 non-null    category
#  2   uid                      971 non-null    int32
#  3   lat                      971 non-null    float64
#  4   lng                      971 non-null    float64
#  5   bike                     971 non-null    bool
#  6   name                     279 non-null    category
#  7   station_number           279 non-null    object
#  8   booked_bikes             971 non-null    int32
#  9   bikes                    971 non-null    int32
#  10  bikes_available_to_rent  968 non-null    object
#  11  bike_racks               115 non-null    object
#  12  free_racks               971 non-null    int32
#  13  maintenance              971 non-null    bool
#  14  terminal_type            155 non-null    category
#  15  place_type               971 non-null    int32
#  16  rack_locks               971 non-null    bool
#  17  no_registration          971 non-null    bool
#  18  bike_number              971 non-null    int32
#  19  bike_type                971 non-null    int32
#  20  lock_types               971 non-null    category
#  21  active                   971 non-null    bool
#  22  state                    971 non-null    category
#  23  electric_lock            971 non-null    bool
#  24  boardcomputer            971 non-null    float64
# dtypes: bool(6), category(6), float64(3), int32(7), object(3)
# memory usage: 89.1+ KB

# %%
df[df.bike  == False]
# Out:
#         city           time_stamp        uid        lat        lng   bike  \
# 0    Dresden  2024-01-01 23:59:00   32938439  51.056030  13.722850  False
# 1    Dresden  2024-01-01 23:59:00   32938439  51.056030  13.722850  False
# 2    Dresden  2024-01-01 23:59:00   32938439  51.056030  13.722850  False
# 3    Dresden  2024-01-01 23:59:00   32938697  51.057930  13.745820  False
# 4    Dresden  2024-01-01 23:59:00   32938697  51.057930  13.745820  False
# ..       ...                  ...        ...        ...        ...    ...
# 274  Dresden  2024-01-01 23:59:00  286143614  51.051450  13.707135  False
# 275  Dresden  2024-01-01 23:59:00  286143614  51.051450  13.707135  False
# 276  Dresden  2024-01-01 23:59:00  286143614  51.051450  13.707135  False
# 277  Dresden  2024-01-01 23:59:00  317160801  51.041376  13.720036  False
# 278  Dresden  2024-01-01 23:59:00  317160801  51.041376  13.720036  False
#
#                              name station_number  booked_bikes  bikes  \
# 0         MOBIpunkt Bahnhof Mitte          43001             0      3
# 1         MOBIpunkt Bahnhof Mitte          43001             0      3
# 2         MOBIpunkt Bahnhof Mitte          43001             0      3
# 3           MOBIpunkt Carolaplatz          43011             0      6
# 4           MOBIpunkt Carolaplatz          43011             0      6
# ..                            ...            ...           ...    ...
# 274              Semmelweißstraße          43163             0      3
# 275              Semmelweißstraße          43163             0      3
# 276              Semmelweißstraße          43163             0      3
# 277  MOBIpunkt Agentur für Arbeit          43220             0      2
# 278  MOBIpunkt Agentur für Arbeit          43220             0      2
#
#     bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 0                         3          6           3        False           NaN
# 1                         3          6           3        False           NaN
# 2                         3          6           3        False           NaN
# 3                         6          5           0        False           NaN
# 4                         6          5           0        False           NaN
# ..                      ...        ...         ...          ...           ...
# 274                       3        NaN           0        False          free
# 275                       3        NaN           0        False          free
# 276                       3        NaN           0        False          free
# 277                       2          6           4        False           NaN
# 278                       2          6           4        False           NaN
#
#      place_type  rack_locks  no_registration  bike_number  bike_type  \
# 0            18       False            False       931025        150
# 1            18       False            False       930497        196
# 2            18       False            False       931639        196
# 3            18       False            False       930843        150
# 4            18       False            False       930467        196
# ..          ...         ...              ...          ...        ...
# 274          17       False            False       930408        150
# 275          17       False            False       931392        196
# 276          17       False            False       931359        196
# 277          18       False            False       930400        196
# 278          18       False            False       930132        196
#
#          lock_types  active state  electric_lock  boardcomputer
# 0    frame_lock,dls    True    ok           True   7.551015e+09
# 1    frame_lock,dls    True    ok           True   7.551154e+09
# 2    frame_lock,dls    True    ok           True   7.551153e+09
# 3    frame_lock,dls    True    ok           True   7.551060e+09
# 4    frame_lock,dls    True    ok           True   7.551168e+09
# ..              ...     ...   ...            ...            ...
# 274  frame_lock,dls    True    ok           True   7.551059e+09
# 275  frame_lock,dls    True    ok           True   7.551136e+09
# 276  frame_lock,dls    True    ok           True   7.551133e+09
# 277  frame_lock,dls    True    ok           True   7.551168e+09
# 278  frame_lock,dls    True    ok           True   7.551163e+09
#
# [279 rows x 25 columns]

# %%
df[df.bike  == False].groupby("uid").size().sort_values()
# Out:
# uid
# 32939013      1
# 32939177      1
# 32941248      1
# 40095111      1
# 41566991      1
#              ..
# 44177530     10
# 218635763    10
# 218509263    12
# 40095125     12
# 43315750     13
# Length: 119, dtype: int64

# %%
df[df.bike  == True].groupby("uid").size().sort_values()
# Out:
# uid
# 339574996    1
# 339574981    1
# 339574929    1
# 339574926    1
# 339574906    1
#             ..
# 339393353    1
# 339575073    1
# 339575105    1
# 339575114    1
# 339128630    1
# Length: 692, dtype: int64

# %%
df[df.bike  == True]
# Out:
#         city           time_stamp        uid        lat        lng  bike name  \
# 279  Dresden  2024-01-01 23:59:00  339128630  51.054409  13.738538  True  NaN
# 280  Dresden  2024-01-01 23:59:00  339169016  51.073031  13.730790  True  NaN
# 281  Dresden  2024-01-01 23:59:00  339191891  51.018978  13.780988  True  NaN
# 282  Dresden  2024-01-01 23:59:00  339202497  51.058276  13.764534  True  NaN
# 283  Dresden  2024-01-01 23:59:00  339202645  51.039493  13.792641  True  NaN
# ..       ...                  ...        ...        ...        ...   ...  ...
# 966  Dresden  2024-01-01 23:59:00  339574996  51.094324  13.726396  True  NaN
# 967  Dresden  2024-01-01 23:59:00  339575015  51.052240  13.757703  True  NaN
# 968  Dresden  2024-01-01 23:59:00  339575073  51.041489  13.730721  True  NaN
# 969  Dresden  2024-01-01 23:59:00  339575105  51.090684  13.711403  True  NaN
# 970  Dresden  2024-01-01 23:59:00  339575114  51.046831  13.795672  True  NaN
#
#     station_number  booked_bikes  bikes bikes_available_to_rent bike_racks  \
# 279            NaN             0      1                       1        NaN
# 280            NaN             0      1                       1        NaN
# 281            NaN             0      1                       1        NaN
# 282            NaN             0      1                       1        NaN
# 283            NaN             0      1                       1        NaN
# ..             ...           ...    ...                     ...        ...
# 966            NaN             0      1                       1        NaN
# 967            NaN             0      1                       1        NaN
# 968            NaN             0      1                       1        NaN
# 969            NaN             0      1                       1        NaN
# 970            NaN             0      1                       1        NaN
#
#      free_racks  maintenance terminal_type  place_type  rack_locks  \
# 279           0        False           NaN          12       False
# 280           0        False           NaN          12       False
# 281           0        False           NaN          12       False
# 282           0        False           NaN          12       False
# 283           0        False           NaN          12       False
# ..          ...          ...           ...         ...         ...
# 966           0        False           NaN          12       False
# 967           0        False           NaN          12       False
# 968           0        False           NaN          12       False
# 969           0        False           NaN          12       False
# 970           0        False           NaN          12       False
#
#      no_registration  bike_number  bike_type      lock_types  active state  \
# 279            False       931106        150  frame_lock,dls    True    ok
# 280            False       930528        196  frame_lock,dls    True    ok
# 281            False       931268        196  frame_lock,dls    True    ok
# 282            False       930272        196  frame_lock,dls    True    ok
# 283            False       931194        196  frame_lock,dls    True    ok
# ..               ...          ...        ...             ...     ...   ...
# 966            False       930756        150  frame_lock,dls    True    ok
# 967            False       931658        196  frame_lock,dls    True    ok
# 968            False       930069        196  frame_lock,dls    True    ok
# 969            False       930375        196  frame_lock,dls    True    ok
# 970            False       930245        196  frame_lock,dls    True    ok
#
#      electric_lock  boardcomputer
# 279           True   7.551063e+09
# 280           True   7.551169e+09
# 281           True   7.551160e+09
# 282           True   7.551171e+09
# 283           True   7.551135e+09
# ..             ...            ...
# 966           True   7.551048e+09
# 967           True   7.551154e+09
# 968           True   7.551163e+09
# 969           True   7.551170e+09
# 970           True   7.551141e+09
#
# [692 rows x 25 columns]

# %%
df[df.station_number==43005]
# Out:
# Empty DataFrame
# Columns: [city, time_stamp, uid, lat, lng, bike, name, station_number, booked_bikes, bikes, bikes_available_to_rent, bike_racks, free_racks, maintenance, terminal_type, place_type, rack_locks, no_registration, bike_number, bike_type, lock_types, active, state, electric_lock, boardcomputer]
# Index: []

# %%
df[df.station_number==43010]
# Out:
#        city           time_stamp       uid        lat        lng   bike  \
# 17  Dresden  2024-01-01 23:59:00  32940026  51.043182  13.701126  False
# 18  Dresden  2024-01-01 23:59:00  32940026  51.043182  13.701126  False
# 19  Dresden  2024-01-01 23:59:00  32940026  51.043182  13.701126  False
#
#                             name station_number  booked_bikes  bikes  \
# 17  MOBIpunkt Reisewitzer Straße          43010             0      3
# 18  MOBIpunkt Reisewitzer Straße          43010             0      3
# 19  MOBIpunkt Reisewitzer Straße          43010             0      3
#
#    bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 17                       3          5           2         True           NaN
# 18                       3          5           2         True           NaN
# 19                       3          5           2         True           NaN
#
#     place_type  rack_locks  no_registration  bike_number  bike_type  \
# 17          21       False            False       931443        196
# 18          21       False            False       931301        196
# 19          21       False            False       931667        196
#
#         lock_types  active state  electric_lock  boardcomputer
# 17  frame_lock,dls    True    ok           True   7.551163e+09
# 18  frame_lock,dls    True    ok           True   7.551143e+09
# 19  frame_lock,dls    True    ok           True   7.551154e+09

# %%
df[df.maintenance==True]
# Out:
#        city           time_stamp       uid        lat        lng   bike  \
# 17  Dresden  2024-01-01 23:59:00  32940026  51.043182  13.701126  False
# 18  Dresden  2024-01-01 23:59:00  32940026  51.043182  13.701126  False
# 19  Dresden  2024-01-01 23:59:00  32940026  51.043182  13.701126  False
#
#                             name station_number  booked_bikes  bikes  \
# 17  MOBIpunkt Reisewitzer Straße          43010             0      3
# 18  MOBIpunkt Reisewitzer Straße          43010             0      3
# 19  MOBIpunkt Reisewitzer Straße          43010             0      3
#
#    bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 17                       3          5           2         True           NaN
# 18                       3          5           2         True           NaN
# 19                       3          5           2         True           NaN
#
#     place_type  rack_locks  no_registration  bike_number  bike_type  \
# 17          21       False            False       931443        196
# 18          21       False            False       931301        196
# 19          21       False            False       931667        196
#
#         lock_types  active state  electric_lock  boardcomputer
# 17  frame_lock,dls    True    ok           True   7.551163e+09
# 18  frame_lock,dls    True    ok           True   7.551143e+09
# 19  frame_lock,dls    True    ok           True   7.551154e+09

# %% [markdown]
# # columns loop

# %%
for col in df.columns:
    print(col.upper())
    print( f"{len(df[col].unique())} unique values" )
    print(df.groupby(col).size().sort_values(ascending=False).head(5))
    print()
# Out:
# CITY
# 1 unique values
# city
# Dresden    971
# dtype: int64
#
# TIME_STAMP
# 1 unique values
# time_stamp
# 2024-01-01 23:59:00    971
# dtype: int64
#
# UID
# 811 unique values
# uid
# 43315750     13
# 218509263    12
# 40095125     12
# 44177530     10
# 218635763    10
# dtype: int64
#
# LAT
# 780 unique values
# lat
# 51.082206    13
# 51.025768    12
# 51.060922    12
# 50.996300    10
# 51.052413    10
# dtype: int64
#
# LNG
# 800 unique values
# lng
# 13.695724    13
# 13.676932    12
# 13.826696    12
# 13.867730    10
# 13.741953    10
# dtype: int64
#
# BIKE
# 2 unique values
# bike
# True     692
# False    279
# dtype: int64
#
# NAME
# 120 unique values
# name
# MOBIpunkt ELBEPARK                   13
# MOBIpunkt Gottfried-Keller-Straße    12
# Donathstraße                         12
# Frauenkirche                         10
# Wilhelm-Weitling-Straße              10
# dtype: int64
#
# STATION_NUMBER
# 120 unique values
# station_number
# 43056    13
# 43036    12
# 43228    12
# 43303    10
# 43051    10
# dtype: int64
#
# BOOKED_BIKES
# 2 unique values
# booked_bikes
# 0    968
# 1      3
# dtype: int64
#
# BIKES
# 10 unique values
# bikes
# 1    757
# 2     44
# 3     36
# 5     30
# 6     24
# dtype: int64
#
# BIKES_AVAILABLE_TO_RENT
# 11 unique values
# bikes_available_to_rent
# 1    754
# 2     44
# 3     36
# 5     30
# 6     24
# dtype: int64
#
# BIKE_RACKS
# 6 unique values
# bike_racks
# 6     84
# 5     17
# 4      9
# 3      4
# 10     1
# dtype: int64
#
# FREE_RACKS
# 7 unique values
# free_racks
# 0    916
# 1     13
# 2     11
# 3     11
# 4     11
# dtype: int64
#
# MAINTENANCE
# 2 unique values
# maintenance
# False    968
# True       3
# dtype: int64
#
# TERMINAL_TYPE
# 2 unique values
# terminal_type
# free    155
# dtype: int64
#
# PLACE_TYPE
# 5 unique values
# place_type
# 12    691
# 17    149
# 18    114
# 21     16
# 22      1
# dtype: int64
#
# RACK_LOCKS
# 1 unique values
# rack_locks
# False    971
# dtype: int64
#
# NO_REGISTRATION
# 1 unique values
# no_registration
# False    971
# dtype: int64
#
# BIKE_NUMBER
# 971 unique values
# bike_number
# 931806    1
# 930001    1
# 930005    1
# 930006    1
# 930007    1
# dtype: int64
#
# BIKE_TYPE
# 5 unique values
# bike_type
# 196    752
# 150    216
# 276      1
# 279      1
# 283      1
# dtype: int64
#
# LOCK_TYPES
# 2 unique values
# lock_types
# frame_lock,dls    960
# frame_lock         11
# dtype: int64
#
# ACTIVE
# 1 unique values
# active
# True    971
# dtype: int64
#
# STATE
# 1 unique values
# state
# ok    971
# dtype: int64
#
# ELECTRIC_LOCK
# 1 unique values
# electric_lock
# True    971
# dtype: int64
#
# BOARDCOMPUTER
# 971 unique values
# boardcomputer
# 8.330000e+10    1
# 7.551004e+09    1
# 7.551005e+09    1
# 7.551015e+09    1
# 7.551015e+09    1
# dtype: int64
# /var/folders/zz/b00th7c11zqbbg9m2fhn24d40000gp/T/ipykernel_16323/2070826361.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby(col).size().sort_values(ascending=False).head(5))
# /var/folders/zz/b00th7c11zqbbg9m2fhn24d40000gp/T/ipykernel_16323/2070826361.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby(col).size().sort_values(ascending=False).head(5))
# /var/folders/zz/b00th7c11zqbbg9m2fhn24d40000gp/T/ipykernel_16323/2070826361.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby(col).size().sort_values(ascending=False).head(5))
# /var/folders/zz/b00th7c11zqbbg9m2fhn24d40000gp/T/ipykernel_16323/2070826361.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby(col).size().sort_values(ascending=False).head(5))
# /var/folders/zz/b00th7c11zqbbg9m2fhn24d40000gp/T/ipykernel_16323/2070826361.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby(col).size().sort_values(ascending=False).head(5))
# /var/folders/zz/b00th7c11zqbbg9m2fhn24d40000gp/T/ipykernel_16323/2070826361.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby(col).size().sort_values(ascending=False).head(5))

# %% [markdown]
# # daytime bike dataset

# %%
result = pyreadr.read_r('../data/Dresden_01-03.24/2024-01-10/2024-01-10-13-15-00.rds')
# 10.01.2024 is Wednesday
df_daytime = result[None]

# %%
len(df_daytime)
# Out:
# 946

# %%
df_daytime
# Out:
#         city           time_stamp        uid        lat        lng   bike  \
# 0    Dresden  2024-01-10 13:15:00       6768  51.046642  13.771276  False
# 1    Dresden  2024-01-10 13:15:00       6768  51.046642  13.771276  False
# 2    Dresden  2024-01-10 13:15:00       6768  51.046642  13.771276  False
# 3    Dresden  2024-01-10 13:15:00       6768  51.046642  13.771276  False
# 4    Dresden  2024-01-10 13:15:00       6768  51.046642  13.771276  False
# ..       ...                  ...        ...        ...        ...    ...
# 941  Dresden  2024-01-10 13:15:00  343531734  51.032707  13.710734   True
# 942  Dresden  2024-01-10 13:15:00  343531787  51.033049  13.737970   True
# 943  Dresden  2024-01-10 13:15:00  343531811  51.035996  13.718240   True
# 944  Dresden  2024-01-10 13:15:00  343531866  51.035924  13.731620   True
# 945  Dresden  2024-01-10 13:15:00  343531963  51.065107  13.752950   True
#
#                         name station_number  booked_bikes  bikes  \
# 0    MOBIpunkt Fetscherplatz          43004             0     14
# 1    MOBIpunkt Fetscherplatz          43004             0     14
# 2    MOBIpunkt Fetscherplatz          43004             0     14
# 3    MOBIpunkt Fetscherplatz          43004             0     14
# 4    MOBIpunkt Fetscherplatz          43004             0     14
# ..                       ...            ...           ...    ...
# 941                      NaN            NaN             0      1
# 942                      NaN            NaN             0      1
# 943                      NaN            NaN             0      1
# 944                      NaN            NaN             0      1
# 945                      NaN            NaN             0      1
#
#     bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 0                        14          6           0        False           NaN
# 1                        14          6           0        False           NaN
# 2                        14          6           0        False           NaN
# 3                        14          6           0        False           NaN
# 4                        14          6           0        False           NaN
# ..                      ...        ...         ...          ...           ...
# 941                       1        NaN           0        False           NaN
# 942                       1        NaN           0        False           NaN
# 943                       1        NaN           0        False           NaN
# 944                       1        NaN           0        False           NaN
# 945                       1        NaN           0        False           NaN
#
#      place_type  rack_locks  no_registration  bike_number  bike_type  \
# 0            21       False            False       930536        196
# 1            21       False            False       930478        150
# 2            21       False            False       930366        196
# 3            21       False            False       930268        196
# 4            21       False            False       930099        150
# ..          ...         ...              ...          ...        ...
# 941          12       False            False       931194        196
# 942          12       False            False       931390        196
# 943          12       False            False       931470        196
# 944          12       False            False       930817        196
# 945          12       False            False       930876        196
#
#          lock_types  active state  electric_lock  boardcomputer
# 0    frame_lock,dls    True    ok           True   7.551169e+09
# 1    frame_lock,dls    True    ok           True   7.551171e+09
# 2    frame_lock,dls    True    ok           True   7.551163e+09
# 3    frame_lock,dls    True    ok           True   7.551154e+09
# 4    frame_lock,dls    True    ok           True   7.551048e+09
# ..              ...     ...   ...            ...            ...
# 941  frame_lock,dls    True    ok           True   7.551135e+09
# 942  frame_lock,dls    True    ok           True   7.551164e+09
# 943  frame_lock,dls    True    ok           True   7.551157e+09
# 944  frame_lock,dls    True    ok           True   7.551170e+09
# 945  frame_lock,dls    True    ok           True   7.551158e+09
#
# [946 rows x 25 columns]

# %%
df_daytime[df_daytime.booked_bikes!=0]
# Out:
#         city           time_stamp        uid        lat        lng   bike  \
# 67   Dresden  2024-01-10 13:15:00   32941375  51.033300  13.783570  False
# 354  Dresden  2024-01-10 13:15:00  343439422  51.057089  13.749706   True
# 389  Dresden  2024-01-10 13:15:00  343450779  51.060182  13.771467   True
# 527  Dresden  2024-01-10 13:15:00  343486016  51.043133  13.775631   True
# 540  Dresden  2024-01-10 13:15:00  343487585  51.052969  13.735596   True
# 579  Dresden  2024-01-10 13:15:00  343494773  51.030560  13.708421   True
# 779  Dresden  2024-01-10 13:15:00  343521455  51.030796  13.701140   True
# 816  Dresden  2024-01-10 13:15:00  343524325  51.027716  13.754106   True
# 830  Dresden  2024-01-10 13:15:00  343524961  51.025489  13.759398   True
# 855  Dresden  2024-01-10 13:15:00  343527291  51.033302  13.711562   True
# 895  Dresden  2024-01-10 13:15:00  343529043  51.058098  13.767621   True
# 937  Dresden  2024-01-10 13:15:00  343531635  51.061071  13.750259   True
#
#                         name station_number  booked_bikes  bikes  \
# 67   MOBIpunkt Zwinglistraße          43009             1      1
# 354                      NaN            NaN             1      1
# 389                      NaN            NaN             1      1
# 527                      NaN            NaN             1      1
# 540                      NaN            NaN             1      1
# 579                      NaN            NaN             1      1
# 779                      NaN            NaN             1      1
# 816                      NaN            NaN             1      1
# 830                      NaN            NaN             1      1
# 855                      NaN            NaN             1      1
# 895                      NaN            NaN             1      1
# 937                      NaN            NaN             1      1
#
#     bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 67                      NaN          6           5        False           NaN
# 354                     NaN        NaN           0        False           NaN
# 389                     NaN        NaN           0        False           NaN
# 527                     NaN        NaN           0        False           NaN
# 540                     NaN        NaN           0        False           NaN
# 579                     NaN        NaN           0        False           NaN
# 779                     NaN        NaN           0        False           NaN
# 816                     NaN        NaN           0        False           NaN
# 830                     NaN        NaN           0        False           NaN
# 855                     NaN        NaN           0        False           NaN
# 895                     NaN        NaN           0        False           NaN
# 937                     NaN        NaN           0        False           NaN
#
#      place_type  rack_locks  no_registration  bike_number  bike_type  \
# 67           18       False            False       931651        196
# 354          12       False            False       930763        150
# 389          12       False            False       931562        196
# 527          12       False            False       931183        196
# 540          12       False            False       931410        196
# 579          12       False            False       931674        196
# 779          12       False            False       931071        150
# 816          12       False            False       931220        196
# 830          12       False            False       930917        150
# 855          12       False            False       930857        150
# 895          12       False            False       930402        196
# 937          12       False            False       931624        196
#
#          lock_types  active state  electric_lock  boardcomputer
# 67   frame_lock,dls    True    ok           True   7.551153e+09
# 354  frame_lock,dls    True    ok           True   7.551048e+09
# 389  frame_lock,dls    True    ok           True   7.551154e+09
# 527  frame_lock,dls    True    ok           True   7.551133e+09
# 540  frame_lock,dls    True    ok           True   7.551164e+09
# 579  frame_lock,dls    True    ok           True   7.551153e+09
# 779  frame_lock,dls    True    ok           True   7.551015e+09
# 816  frame_lock,dls    True    ok           True   7.551133e+09
# 830  frame_lock,dls    True    ok           True   7.551061e+09
# 855  frame_lock,dls    True    ok           True   7.551063e+09
# 895  frame_lock,dls    True    ok           True   7.551161e+09
# 937  frame_lock,dls    True    ok           True   7.551155e+09

# %%
df_daytime[df_daytime.station_number==43001]
# Out:
#        city           time_stamp       uid       lat       lng   bike  \
# 14  Dresden  2024-01-10 13:15:00  32938439  51.05603  13.72285  False
#
#                        name station_number  booked_bikes  bikes  \
# 14  MOBIpunkt Bahnhof Mitte          43001             0      1
#
#    bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 14                       1          6           5        False           NaN
#
#     place_type  rack_locks  no_registration  bike_number  bike_type  \
# 14          18       False            False       931798        196
#
#         lock_types  active state  electric_lock  boardcomputer
# 14  frame_lock,dls    True    ok           True   7.551153e+09

# %%
df_daytime[df_daytime.maintenance==True]
# Out:
# Empty DataFrame
# Columns: [city, time_stamp, uid, lat, lng, bike, name, station_number, booked_bikes, bikes, bikes_available_to_rent, bike_racks, free_racks, maintenance, terminal_type, place_type, rack_locks, no_registration, bike_number, bike_type, lock_types, active, state, electric_lock, boardcomputer]
# Index: []

# %%
# in the daytime, there are little more booked bikes

# %%
df_daytime[df_daytime.bikes>10]
# Out:
#         city           time_stamp       uid        lat        lng   bike  \
# 0    Dresden  2024-01-10 13:15:00      6768  51.046642  13.771276  False
# 1    Dresden  2024-01-10 13:15:00      6768  51.046642  13.771276  False
# 2    Dresden  2024-01-10 13:15:00      6768  51.046642  13.771276  False
# 3    Dresden  2024-01-10 13:15:00      6768  51.046642  13.771276  False
# 4    Dresden  2024-01-10 13:15:00      6768  51.046642  13.771276  False
# ..       ...                  ...       ...        ...        ...    ...
# 118  Dresden  2024-01-10 13:15:00  43315750  51.082206  13.695724  False
# 119  Dresden  2024-01-10 13:15:00  43315750  51.082206  13.695724  False
# 120  Dresden  2024-01-10 13:15:00  43315750  51.082206  13.695724  False
# 121  Dresden  2024-01-10 13:15:00  43315750  51.082206  13.695724  False
# 122  Dresden  2024-01-10 13:15:00  43315750  51.082206  13.695724  False
#
#                         name station_number  booked_bikes  bikes  \
# 0    MOBIpunkt Fetscherplatz          43004             0     14
# 1    MOBIpunkt Fetscherplatz          43004             0     14
# 2    MOBIpunkt Fetscherplatz          43004             0     14
# 3    MOBIpunkt Fetscherplatz          43004             0     14
# 4    MOBIpunkt Fetscherplatz          43004             0     14
# ..                       ...            ...           ...    ...
# 118       MOBIpunkt ELBEPARK          43056             0     11
# 119       MOBIpunkt ELBEPARK          43056             0     11
# 120       MOBIpunkt ELBEPARK          43056             0     11
# 121       MOBIpunkt ELBEPARK          43056             0     11
# 122       MOBIpunkt ELBEPARK          43056             0     11
#
#     bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 0                        14          6           0        False           NaN
# 1                        14          6           0        False           NaN
# 2                        14          6           0        False           NaN
# 3                        14          6           0        False           NaN
# 4                        14          6           0        False           NaN
# ..                      ...        ...         ...          ...           ...
# 118                      11          6           0        False           NaN
# 119                      11          6           0        False           NaN
# 120                      11          6           0        False           NaN
# 121                      11          6           0        False           NaN
# 122                      11          6           0        False           NaN
#
#      place_type  rack_locks  no_registration  bike_number  bike_type  \
# 0            21       False            False       930536        196
# 1            21       False            False       930478        150
# 2            21       False            False       930366        196
# 3            21       False            False       930268        196
# 4            21       False            False       930099        150
# ..          ...         ...              ...          ...        ...
# 118          18       False            False       931408        196
# 119          18       False            False       931322        196
# 120          18       False            False       931267        196
# 121          18       False            False       931614        196
# 122          18       False            False       931526        196
#
#          lock_types  active state  electric_lock  boardcomputer
# 0    frame_lock,dls    True    ok           True   7.551169e+09
# 1    frame_lock,dls    True    ok           True   7.551171e+09
# 2    frame_lock,dls    True    ok           True   7.551163e+09
# 3    frame_lock,dls    True    ok           True   7.551154e+09
# 4    frame_lock,dls    True    ok           True   7.551048e+09
# ..              ...     ...   ...            ...            ...
# 118  frame_lock,dls    True    ok           True   7.551164e+09
# 119  frame_lock,dls    True    ok           True   7.551164e+09
# 120  frame_lock,dls    True    ok           True   7.551137e+09
# 121  frame_lock,dls    True    ok           True   7.551161e+09
# 122  frame_lock,dls    True    ok           True   7.551153e+09
#
# [52 rows x 25 columns]

# %%
df_daytime[df_daytime.station_number==43005]
# Out:
# Empty DataFrame
# Columns: [city, time_stamp, uid, lat, lng, bike, name, station_number, booked_bikes, bikes, bikes_available_to_rent, bike_racks, free_racks, maintenance, terminal_type, place_type, rack_locks, no_registration, bike_number, bike_type, lock_types, active, state, electric_lock, boardcomputer]
# Index: []

# %%
df_daytime.place_type.unique()
# Out:
# array([21, 18, 17, 12], dtype=int32)

# %%
df_daytime[df_daytime.place_type==21]
# Out:
#         city           time_stamp       uid        lat        lng   bike  \
# 0    Dresden  2024-01-10 13:15:00      6768  51.046642  13.771276  False
# 1    Dresden  2024-01-10 13:15:00      6768  51.046642  13.771276  False
# 2    Dresden  2024-01-10 13:15:00      6768  51.046642  13.771276  False
# 3    Dresden  2024-01-10 13:15:00      6768  51.046642  13.771276  False
# 4    Dresden  2024-01-10 13:15:00      6768  51.046642  13.771276  False
# ..       ...                  ...       ...        ...        ...    ...
# 73   Dresden  2024-01-10 13:15:00  34123624  51.075384  13.749819  False
# 74   Dresden  2024-01-10 13:15:00  34123624  51.075384  13.749819  False
# 148  Dresden  2024-01-10 13:15:00  54163083  51.022731  13.839169  False
# 187  Dresden  2024-01-10 13:15:00  75387190  51.050396  13.731514  False
# 188  Dresden  2024-01-10 13:15:00  75387190  51.050396  13.731514  False
#
#                               name station_number  booked_bikes  bikes  \
# 0          MOBIpunkt Fetscherplatz          43004             0     14
# 1          MOBIpunkt Fetscherplatz          43004             0     14
# 2          MOBIpunkt Fetscherplatz          43004             0     14
# 3          MOBIpunkt Fetscherplatz          43004             0     14
# 4          MOBIpunkt Fetscherplatz          43004             0     14
# ..                             ...            ...           ...    ...
# 73   MOBIpunkt Königsbrücker Platz          43025             0      2
# 74   MOBIpunkt Königsbrücker Platz          43025             0      2
# 148    MOBIpunkt Kronstädter Platz          43111             0      1
# 187            MOBIpunkt Postplatz          43140             0      2
# 188            MOBIpunkt Postplatz          43140             0      2
#
#     bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 0                        14          6           0        False           NaN
# 1                        14          6           0        False           NaN
# 2                        14          6           0        False           NaN
# 3                        14          6           0        False           NaN
# 4                        14          6           0        False           NaN
# ..                      ...        ...         ...          ...           ...
# 73                        2          6           4        False           NaN
# 74                        2          6           4        False           NaN
# 148                       1          6           5        False           NaN
# 187                       2          6           4        False           NaN
# 188                       2          6           4        False           NaN
#
#      place_type  rack_locks  no_registration  bike_number  bike_type  \
# 0            21       False            False       930536        196
# 1            21       False            False       930478        150
# 2            21       False            False       930366        196
# 3            21       False            False       930268        196
# 4            21       False            False       930099        150
# ..          ...         ...              ...          ...        ...
# 73           21       False            False       931305        196
# 74           21       False            False       931804        283
# 148          21       False            False       931806        279
# 187          21       False            False       930217        196
# 188          21       False            False       931801        276
#
#          lock_types  active state  electric_lock  boardcomputer
# 0    frame_lock,dls    True    ok           True   7.551169e+09
# 1    frame_lock,dls    True    ok           True   7.551171e+09
# 2    frame_lock,dls    True    ok           True   7.551163e+09
# 3    frame_lock,dls    True    ok           True   7.551154e+09
# 4    frame_lock,dls    True    ok           True   7.551048e+09
# ..              ...     ...   ...            ...            ...
# 73   frame_lock,dls    True    ok           True   7.551135e+09
# 74       frame_lock    True    ok           True   7.551159e+09
# 148      frame_lock    True    ok           True   7.551157e+09
# 187  frame_lock,dls    True    ok           True   7.551171e+09
# 188      frame_lock    True    ok           True   7.551159e+09
#
# [26 rows x 25 columns]

# %%
df_daytime[df_daytime.place_type==17]
# Out:
#         city           time_stamp        uid        lat        lng   bike  \
# 75   Dresden  2024-01-10 13:15:00   40095102  51.027580  13.777880  False
# 76   Dresden  2024-01-10 13:15:00   40095102  51.027580  13.777880  False
# 77   Dresden  2024-01-10 13:15:00   40095102  51.027580  13.777880  False
# 78   Dresden  2024-01-10 13:15:00   40095102  51.027580  13.777880  False
# 79   Dresden  2024-01-10 13:15:00   40095102  51.027580  13.777880  False
# ..       ...                  ...        ...        ...        ...    ...
# 272  Dresden  2024-01-10 13:15:00  306050198  51.054529  13.782524  False
# 273  Dresden  2024-01-10 13:15:00  306050198  51.054529  13.782524  False
# 274  Dresden  2024-01-10 13:15:00  306050198  51.054529  13.782524  False
# 275  Dresden  2024-01-10 13:15:00  306050198  51.054529  13.782524  False
# 276  Dresden  2024-01-10 13:15:00  306050198  51.054529  13.782524  False
#
#                                                name station_number  \
# 75                            DVB-Betriebshof Gruna          43034
# 76                            DVB-Betriebshof Gruna          43034
# 77                            DVB-Betriebshof Gruna          43034
# 78                            DVB-Betriebshof Gruna          43034
# 79                            DVB-Betriebshof Gruna          43034
# ..                                              ...            ...
# 272  SLUB – Bibliothek Fiedlerstraße/Medizin (West)          43164
# 273  SLUB – Bibliothek Fiedlerstraße/Medizin (West)          43164
# 274  SLUB – Bibliothek Fiedlerstraße/Medizin (West)          43164
# 275  SLUB – Bibliothek Fiedlerstraße/Medizin (West)          43164
# 276  SLUB – Bibliothek Fiedlerstraße/Medizin (West)          43164
#
#      booked_bikes  bikes bikes_available_to_rent bike_racks  free_racks  \
# 75              0      6                       6        NaN           0
# 76              0      6                       6        NaN           0
# 77              0      6                       6        NaN           0
# 78              0      6                       6        NaN           0
# 79              0      6                       6        NaN           0
# ..            ...    ...                     ...        ...         ...
# 272             0     10                      10        NaN           0
# 273             0     10                      10        NaN           0
# 274             0     10                      10        NaN           0
# 275             0     10                      10        NaN           0
# 276             0     10                      10        NaN           0
#
#      maintenance terminal_type  place_type  rack_locks  no_registration  \
# 75         False          free          17       False            False
# 76         False          free          17       False            False
# 77         False          free          17       False            False
# 78         False          free          17       False            False
# 79         False          free          17       False            False
# ..           ...           ...         ...         ...              ...
# 272        False          free          17       False            False
# 273        False          free          17       False            False
# 274        False          free          17       False            False
# 275        False          free          17       False            False
# 276        False          free          17       False            False
#
#      bike_number  bike_type      lock_types  active state  electric_lock  \
# 75        931124        196  frame_lock,dls    True    ok           True
# 76        930774        196  frame_lock,dls    True    ok           True
# 77        930346        150  frame_lock,dls    True    ok           True
# 78        930313        196  frame_lock,dls    True    ok           True
# 79        931362        196  frame_lock,dls    True    ok           True
# ..           ...        ...             ...     ...   ...            ...
# 272       930542        196  frame_lock,dls    True    ok           True
# 273       930149        196  frame_lock,dls    True    ok           True
# 274       931585        196  frame_lock,dls    True    ok           True
# 275       931522        196  frame_lock,dls    True    ok           True
# 276       931510        196  frame_lock,dls    True    ok           True
#
#      boardcomputer
# 75    7.551172e+09
# 76    7.551172e+09
# 77    7.551060e+09
# 78    7.551164e+09
# 79    7.551138e+09
# ..             ...
# 272   7.551169e+09
# 273   7.551141e+09
# 274   7.551161e+09
# 275   7.551154e+09
# 276   7.551153e+09
#
# [142 rows x 25 columns]

# %%
df_daytime[df_daytime.place_type==18]
# Out:
#         city           time_stamp        uid        lat        lng   bike  \
# 14   Dresden  2024-01-10 13:15:00   32938439  51.056030  13.722850  False
# 15   Dresden  2024-01-10 13:15:00   32938910  51.077640  13.716860  False
# 16   Dresden  2024-01-10 13:15:00   32938910  51.077640  13.716860  False
# 17   Dresden  2024-01-10 13:15:00   32938910  51.077640  13.716860  False
# 18   Dresden  2024-01-10 13:15:00   32938910  51.077640  13.716860  False
# ..       ...                  ...        ...        ...        ...    ...
# 223  Dresden  2024-01-10 13:15:00  147208943  51.062254  13.855189  False
# 233  Dresden  2024-01-10 13:15:00  205866349  51.080348  13.714119  False
# 234  Dresden  2024-01-10 13:15:00  205866349  51.080348  13.714119  False
# 235  Dresden  2024-01-10 13:15:00  205866349  51.080348  13.714119  False
# 264  Dresden  2024-01-10 13:15:00  277032272  51.067653  13.776606  False
#
#                                    name station_number  booked_bikes  bikes  \
# 14              MOBIpunkt Bahnhof Mitte          43001             0      1
# 15                MOBIpunkt Altpieschen          43015             0     11
# 16                MOBIpunkt Altpieschen          43015             0     11
# 17                MOBIpunkt Altpieschen          43015             0     11
# 18                MOBIpunkt Altpieschen          43015             0     11
# ..                                  ...            ...           ...    ...
# 223        MOBIpunkt Ullersdorfer Platz          43195             0      2
# 233                   MOBIpunkt Mickten          43233             0      3
# 234                   MOBIpunkt Mickten          43233             0      3
# 235                   MOBIpunkt Mickten          43233             0      3
# 264  MOBIpunkt Waldschlösschen (Konsum)          43134             0      1
#
#     bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 14                        1          6           5        False           NaN
# 15                       11          6           0        False           NaN
# 16                       11          6           0        False           NaN
# 17                       11          6           0        False           NaN
# 18                       11          6           0        False           NaN
# ..                      ...        ...         ...          ...           ...
# 223                       2          6           4        False           NaN
# 233                       3          4           1        False           NaN
# 234                       3          4           1        False           NaN
# 235                       3          4           1        False           NaN
# 264                       1         10           9        False           NaN
#
#      place_type  rack_locks  no_registration  bike_number  bike_type  \
# 14           18       False            False       931798        196
# 15           18       False            False       931068        196
# 16           18       False            False       930761        196
# 17           18       False            False       930513        196
# 18           18       False            False       930075        150
# ..          ...         ...              ...          ...        ...
# 223          18       False            False       930408        150
# 233          18       False            False       931100        196
# 234          18       False            False       931705        196
# 235          18       False            False       931597        196
# 264          18       False            False       930114        196
#
#          lock_types  active state  electric_lock  boardcomputer
# 14   frame_lock,dls    True    ok           True   7.551153e+09
# 15   frame_lock,dls    True    ok           True   7.551142e+09
# 16   frame_lock,dls    True    ok           True   7.551162e+09
# 17   frame_lock,dls    True    ok           True   7.551168e+09
# 18   frame_lock,dls    True    ok           True   7.551063e+09
# ..              ...     ...   ...            ...            ...
# 223  frame_lock,dls    True    ok           True   7.551059e+09
# 233  frame_lock,dls    True    ok           True   7.551172e+09
# 234  frame_lock,dls    True    ok           True   7.551153e+09
# 235  frame_lock,dls    True    ok           True   7.551153e+09
# 264  frame_lock,dls    True    ok           True   7.551164e+09
#
# [109 rows x 25 columns]

# %%
df_daytime[(df_daytime.place_type==12) & (df_daytime.bike==True)]
# Out:
#         city           time_stamp        uid        lat        lng  bike name  \
# 277  Dresden  2024-01-10 13:15:00  343184616  51.039471  13.732626  True  NaN
# 278  Dresden  2024-01-10 13:15:00  343250183  51.053476  13.734996  True  NaN
# 279  Dresden  2024-01-10 13:15:00  343271276  51.058844  13.780552  True  NaN
# 280  Dresden  2024-01-10 13:15:00  343280161  51.070711  13.738344  True  NaN
# 281  Dresden  2024-01-10 13:15:00  343291970  51.034036  13.799997  True  NaN
# ..       ...                  ...        ...        ...        ...   ...  ...
# 941  Dresden  2024-01-10 13:15:00  343531734  51.032707  13.710734  True  NaN
# 942  Dresden  2024-01-10 13:15:00  343531787  51.033049  13.737970  True  NaN
# 943  Dresden  2024-01-10 13:15:00  343531811  51.035996  13.718240  True  NaN
# 944  Dresden  2024-01-10 13:15:00  343531866  51.035924  13.731620  True  NaN
# 945  Dresden  2024-01-10 13:15:00  343531963  51.065107  13.752950  True  NaN
#
#     station_number  booked_bikes  bikes bikes_available_to_rent bike_racks  \
# 277            NaN             0      1                       1        NaN
# 278            NaN             0      1                       1        NaN
# 279            NaN             0      1                       1        NaN
# 280            NaN             0      1                       1        NaN
# 281            NaN             0      1                       1        NaN
# ..             ...           ...    ...                     ...        ...
# 941            NaN             0      1                       1        NaN
# 942            NaN             0      1                       1        NaN
# 943            NaN             0      1                       1        NaN
# 944            NaN             0      1                       1        NaN
# 945            NaN             0      1                       1        NaN
#
#      free_racks  maintenance terminal_type  place_type  rack_locks  \
# 277           0        False           NaN          12       False
# 278           0        False           NaN          12       False
# 279           0        False           NaN          12       False
# 280           0        False           NaN          12       False
# 281           0        False           NaN          12       False
# ..          ...          ...           ...         ...         ...
# 941           0        False           NaN          12       False
# 942           0        False           NaN          12       False
# 943           0        False           NaN          12       False
# 944           0        False           NaN          12       False
# 945           0        False           NaN          12       False
#
#      no_registration  bike_number  bike_type      lock_types  active state  \
# 277            False       931547        196  frame_lock,dls    True    ok
# 278            False       930663        150  frame_lock,dls    True    ok
# 279            False       931031        196  frame_lock,dls    True    ok
# 280            False       931056        196  frame_lock,dls    True    ok
# 281            False       930655        196  frame_lock,dls    True    ok
# ..               ...          ...        ...             ...     ...   ...
# 941            False       931194        196  frame_lock,dls    True    ok
# 942            False       931390        196  frame_lock,dls    True    ok
# 943            False       931470        196  frame_lock,dls    True    ok
# 944            False       930817        196  frame_lock,dls    True    ok
# 945            False       930876        196  frame_lock,dls    True    ok
#
#      electric_lock  boardcomputer
# 277           True   7.551158e+09
# 278           True   7.551060e+09
# 279           True   7.551169e+09
# 280           True   7.551158e+09
# 281           True   7.551164e+09
# ..             ...            ...
# 941           True   7.551135e+09
# 942           True   7.551164e+09
# 943           True   7.551157e+09
# 944           True   7.551170e+09
# 945           True   7.551158e+09
#
# [669 rows x 25 columns]

# %%
name_place_type_gr = df_daytime.groupby(["name", "place_type"]).size()
name_place_type_gr = name_place_type_gr[name_place_type_gr!=0]
# Out:
# /var/folders/zz/b00th7c11zqbbg9m2fhn24d40000gp/T/ipykernel_16323/160800284.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   name_place_type_gr = df_daytime.groupby(["name", "place_type"]).size()

# %%
df_daytime.no_registration.unique()
# Out:
# array([False])

# %% [markdown]
# # rushhour bike dataset

# %%
result = pyreadr.read_r('../data/Dresden_01-03.24/2024-01-31/2024-01-31-08-15-00.rds') # Wednesday
df_rushhour = result[None]

# %%
len(df_rushhour)
# Out:
# 1135

# %%
df_rushhour
# Out:
#          city           time_stamp        uid        lat        lng   bike  \
# 0     Dresden  2024-01-31 08:15:00       6768  51.046642  13.771276  False
# 1     Dresden  2024-01-31 08:15:00   32938697  51.057930  13.745820  False
# 2     Dresden  2024-01-31 08:15:00   32939517  51.048930  13.744200  False
# 3     Dresden  2024-01-31 08:15:00   32939517  51.048930  13.744200  False
# 4     Dresden  2024-01-31 08:15:00   32939517  51.048930  13.744200  False
# ...       ...                  ...        ...        ...        ...    ...
# 1130  Dresden  2024-01-31 08:15:00  353478177  51.041418  13.786896   True
# 1131  Dresden  2024-01-31 08:15:00  353478194  51.071218  13.742323   True
# 1132  Dresden  2024-01-31 08:15:00  353478196  51.045467  13.813232   True
# 1133  Dresden  2024-01-31 08:15:00  353478226  51.069013  13.738430   True
# 1134  Dresden  2024-01-31 08:15:00  353478265  51.039111  13.732619   True
#
#                              name station_number  booked_bikes  bikes  \
# 0         MOBIpunkt Fetscherplatz          43004             0      1
# 1           MOBIpunkt Carolaplatz          43011             0      1
# 2     MOBIpunkt Pirnaischer Platz          43003             0     18
# 3     MOBIpunkt Pirnaischer Platz          43003             0     18
# 4     MOBIpunkt Pirnaischer Platz          43003             0     18
# ...                           ...            ...           ...    ...
# 1130                          NaN            NaN             0      1
# 1131                          NaN            NaN             0      1
# 1132                          NaN            NaN             0      1
# 1133                          NaN            NaN             0      1
# 1134                          NaN            NaN             0      1
#
#      bikes_available_to_rent bike_racks  free_racks  maintenance  \
# 0                          1          6           5        False
# 1                          1          5           4        False
# 2                         18         12           0        False
# 3                         18         12           0        False
# 4                         18         12           0        False
# ...                      ...        ...         ...          ...
# 1130                       1        NaN           0        False
# 1131                       1        NaN           0        False
# 1132                       1        NaN           0        False
# 1133                       1        NaN           0        False
# 1134                       1        NaN           0        False
#
#      terminal_type  place_type  rack_locks  no_registration  bike_number  \
# 0              NaN          21       False            False       930301
# 1              NaN          18       False            False       930675
# 2              NaN          18       False            False       931142
# 3              NaN          18       False            False       930805
# 4              NaN          18       False            False       930768
# ...            ...         ...         ...              ...          ...
# 1130           NaN          12       False            False       931624
# 1131           NaN          12       False            False       931791
# 1132           NaN          12       False            False       931327
# 1133           NaN          12       False            False       931187
# 1134           NaN          12       False            False       930609
#
#       bike_type      lock_types  active state  electric_lock  boardcomputer
# 0           150  frame_lock,dls    True    ok           True   7.551048e+09
# 1           196  frame_lock,dls    True    ok           True   7.551172e+09
# 2           196  frame_lock,dls    True    ok           True   7.551155e+09
# 3           196  frame_lock,dls    True    ok           True   7.551171e+09
# 4           196  frame_lock,dls    True    ok           True   7.551139e+09
# ...         ...             ...     ...   ...            ...            ...
# 1130        196  frame_lock,dls    True    ok           True   7.551155e+09
# 1131        196  frame_lock,dls    True    ok           True   7.551153e+09
# 1132        196  frame_lock,dls    True    ok           True   7.551143e+09
# 1133        196  frame_lock,dls    True    ok           True   7.551144e+09
# 1134        196  frame_lock,dls    True    ok           True   7.551160e+09
#
# [1135 rows x 25 columns]

# %%
len(df_rushhour.station_number.unique())
# Out:
# 124

# %%
ax = sns.heatmap(df_rushhour.isnull(), cbar=True, cmap="Greys")

# %%
df_rushhour[df_rushhour.station_number==43052]
# Out:
#         city           time_stamp       uid        lat        lng   bike  \
# 130  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 131  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 132  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 133  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 134  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 135  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 136  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 137  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 138  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 139  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 140  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 141  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 142  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 143  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 144  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 145  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 146  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 147  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
# 148  Dresden  2024-01-31 08:15:00  42238248  51.040569  13.733552  False
#
#                   name station_number  booked_bikes  bikes  \
# 130  Hauptbahnhof Nord          43052             0     19
# 131  Hauptbahnhof Nord          43052             0     19
# 132  Hauptbahnhof Nord          43052             0     19
# 133  Hauptbahnhof Nord          43052             0     19
# 134  Hauptbahnhof Nord          43052             0     19
# 135  Hauptbahnhof Nord          43052             0     19
# 136  Hauptbahnhof Nord          43052             0     19
# 137  Hauptbahnhof Nord          43052             0     19
# 138  Hauptbahnhof Nord          43052             0     19
# 139  Hauptbahnhof Nord          43052             0     19
# 140  Hauptbahnhof Nord          43052             0     19
# 141  Hauptbahnhof Nord          43052             0     19
# 142  Hauptbahnhof Nord          43052             0     19
# 143  Hauptbahnhof Nord          43052             0     19
# 144  Hauptbahnhof Nord          43052             0     19
# 145  Hauptbahnhof Nord          43052             0     19
# 146  Hauptbahnhof Nord          43052             0     19
# 147  Hauptbahnhof Nord          43052             0     19
# 148  Hauptbahnhof Nord          43052             0     19
#
#     bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 130                      19        NaN           0        False          free
# 131                      19        NaN           0        False          free
# 132                      19        NaN           0        False          free
# 133                      19        NaN           0        False          free
# 134                      19        NaN           0        False          free
# 135                      19        NaN           0        False          free
# 136                      19        NaN           0        False          free
# 137                      19        NaN           0        False          free
# 138                      19        NaN           0        False          free
# 139                      19        NaN           0        False          free
# 140                      19        NaN           0        False          free
# 141                      19        NaN           0        False          free
# 142                      19        NaN           0        False          free
# 143                      19        NaN           0        False          free
# 144                      19        NaN           0        False          free
# 145                      19        NaN           0        False          free
# 146                      19        NaN           0        False          free
# 147                      19        NaN           0        False          free
# 148                      19        NaN           0        False          free
#
#      place_type  rack_locks  no_registration  bike_number  bike_type  \
# 130          17       False            False       930951        150
# 131          17       False            False       930946        150
# 132          17       False            False       930935        150
# 133          17       False            False       930864        196
# 134          17       False            False       930844        150
# 135          17       False            False       930736        196
# 136          17       False            False       930551        150
# 137          17       False            False       930075        150
# 138          17       False            False       930011        196
# 139          17       False            False       931442        196
# 140          17       False            False       931247        196
# 141          17       False            False       931231        196
# 142          17       False            False       931220        196
# 143          17       False            False       931160        196
# 144          17       False            False       931635        196
# 145          17       False            False       931602        196
# 146          17       False            False       931576        196
# 147          17       False            False       931548        196
# 148          17       False            False       931530        196
#
#          lock_types  active state  electric_lock  boardcomputer
# 130  frame_lock,dls    True    ok           True   7.551060e+09
# 131  frame_lock,dls    True    ok           True   7.551143e+09
# 132  frame_lock,dls    True    ok           True   7.551048e+09
# 133  frame_lock,dls    True    ok           True   7.551156e+09
# 134  frame_lock,dls    True    ok           True   7.551051e+09
# 135  frame_lock,dls    True    ok           True   7.551142e+09
# 136  frame_lock,dls    True    ok           True   7.551060e+09
# 137  frame_lock,dls    True    ok           True   7.551063e+09
# 138  frame_lock,dls    True    ok           True   7.551171e+09
# 139      frame_lock    True    ok           True   8.330000e+10
# 140  frame_lock,dls    True    ok           True   7.551132e+09
# 141  frame_lock,dls    True    ok           True   7.551164e+09
# 142  frame_lock,dls    True    ok           True   7.551133e+09
# 143  frame_lock,dls    True    ok           True   7.551137e+09
# 144  frame_lock,dls    True    ok           True   7.551153e+09
# 145  frame_lock,dls    True    ok           True   7.551161e+09
# 146  frame_lock,dls    True    ok           True   7.551154e+09
# 147  frame_lock,dls    True    ok           True   7.551156e+09
# 148  frame_lock,dls    True    ok           True   7.551153e+09

# %%
df_rushhour[df_rushhour.maintenance==True]
# Out:
#        city           time_stamp       uid        lat        lng   bike  \
# 20  Dresden  2024-01-31 08:15:00  32940026  51.043182  13.701126  False
# 21  Dresden  2024-01-31 08:15:00  32940026  51.043182  13.701126  False
# 22  Dresden  2024-01-31 08:15:00  32940026  51.043182  13.701126  False
# 23  Dresden  2024-01-31 08:15:00  32940026  51.043182  13.701126  False
#
#                             name station_number  booked_bikes  bikes  \
# 20  MOBIpunkt Reisewitzer Straße          43010             0      4
# 21  MOBIpunkt Reisewitzer Straße          43010             0      4
# 22  MOBIpunkt Reisewitzer Straße          43010             0      4
# 23  MOBIpunkt Reisewitzer Straße          43010             0      4
#
#    bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 20                       4          5           1         True           NaN
# 21                       4          5           1         True           NaN
# 22                       4          5           1         True           NaN
# 23                       4          5           1         True           NaN
#
#     place_type  rack_locks  no_registration  bike_number  bike_type  \
# 20          21       False            False       930868        196
# 21          21       False            False       930515        196
# 22          21       False            False       931751        196
# 23          21       False            False       931535        196
#
#         lock_types  active state  electric_lock  boardcomputer
# 20  frame_lock,dls    True    ok           True   7.551142e+09
# 21  frame_lock,dls    True    ok           True   7.551141e+09
# 22  frame_lock,dls    True    ok           True   7.551154e+09
# 23  frame_lock,dls    True    ok           True   7.551155e+09

# %%
df_rushhour[df_rushhour.station_number==43010]
# Out:
#        city           time_stamp       uid        lat        lng   bike  \
# 20  Dresden  2024-01-31 08:15:00  32940026  51.043182  13.701126  False
# 21  Dresden  2024-01-31 08:15:00  32940026  51.043182  13.701126  False
# 22  Dresden  2024-01-31 08:15:00  32940026  51.043182  13.701126  False
# 23  Dresden  2024-01-31 08:15:00  32940026  51.043182  13.701126  False
#
#                             name station_number  booked_bikes  bikes  \
# 20  MOBIpunkt Reisewitzer Straße          43010             0      4
# 21  MOBIpunkt Reisewitzer Straße          43010             0      4
# 22  MOBIpunkt Reisewitzer Straße          43010             0      4
# 23  MOBIpunkt Reisewitzer Straße          43010             0      4
#
#    bikes_available_to_rent bike_racks  free_racks  maintenance terminal_type  \
# 20                       4          5           1         True           NaN
# 21                       4          5           1         True           NaN
# 22                       4          5           1         True           NaN
# 23                       4          5           1         True           NaN
#
#     place_type  rack_locks  no_registration  bike_number  bike_type  \
# 20          21       False            False       930868        196
# 21          21       False            False       930515        196
# 22          21       False            False       931751        196
# 23          21       False            False       931535        196
#
#         lock_types  active state  electric_lock  boardcomputer
# 20  frame_lock,dls    True    ok           True   7.551142e+09
# 21  frame_lock,dls    True    ok           True   7.551141e+09
# 22  frame_lock,dls    True    ok           True   7.551154e+09
# 23  frame_lock,dls    True    ok           True   7.551155e+09
